# %% [markdown]
# <a href="https://colab.research.google.com/github/borbysh/quantum-barren-plateaus/blob/main/Tutorials/tutorial_local_cost_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This cell is added by sphinx-gallery
# It can be customized to whatever you like
# %matplotlib inline
# !pip install pennylane
# Out:
# Collecting pennylane
#   Downloading pennylane-0.42.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from pennylane) (3.5)
# Collecting rustworkx>=0.14.0 (from pennylane)
#   Downloading rustworkx-0.16.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: autograd in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.8.0)
# Collecting appdirs (from pennylane)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting autoray>=0.6.11 (from pennylane)
#   Downloading autoray-0.7.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from pennylane) (5.5.2)
# Collecting pennylane-lightning>=0.42 (from pennylane)
#   Downloading pennylane_lightning-0.42.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from pennylane) (2.32.3)
# Requirement already satisfied: tomlkit in /usr/local/lib/python3.11/dist-packages (from pennylane) (0.13.3)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from pennylane) (4.14.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from pennylane) (25.0)
# Collecting diastatic-malt (from pennylane)
#   Downloading diastatic_malt-2.15.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pennylane) (2.0.2)
# Collecting scipy-openblas32>=0.3.26 (from pennylane-lightning>=0.42->pennylane)
#   Downloading scipy_openblas32-0.3.30.0.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: astunparse in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (1.6.3)
# Requirement already satisfied: gast in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (0.6.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (3.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (2025.8.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse->diastatic-malt->pennylane) (0.45.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from astunparse->diastatic-malt->pennylane) (1.17.0)
# Downloading pennylane-0.42.1-py3-none-any.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 51.4 MB/s eta 0:00:00
# Downloading autoray-0.7.2-py3-none-any.whl (930 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.8/930.8 kB 40.0 MB/s eta 0:00:00
# Downloading pennylane_lightning-0.42.0-cp311-cp311-manylinux_2_28_x86_64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 60.8 MB/s eta 0:00:00
# Downloading rustworkx-0.16.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 48.7 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading diastatic_malt-2.15.2-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 kB 10.6 MB/s eta 0:00:00
# Downloading scipy_openblas32-0.3.30.0.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 79.0 MB/s eta 0:00:00
# Installing collected packages: appdirs, scipy-openblas32, rustworkx, autoray, diastatic-malt, pennylane-lightning, pennylane
# Successfully installed appdirs-1.4.4 autoray-0.7.2 diastatic-malt-2.15.2 pennylane-0.42.1 pennylane-lightning-0.42.0 rustworkx-0.16.0 scipy-openblas32-0.3.30.0.2

# %% [markdown]
# # Alleviating barren plateaus with local cost functions
#
# ::: meta
# :property=\"og:description\": Local cost functions are cost formulations
# for variational quantum circuits that are more robust to barren
# plateaus. :property=\"og:image\":
# ../\_static/demonstration_assets/local_cost_functions/Cerezo_et_al_local_cost_functions.png
# :::
#
# ::: related
# tutorial_barren_plateaus Barren plateaus in quantum neural networks
# :::
#
# *Author: Thomas Storwick --- Posted: 09 September 2020. Last updated: 28
# January 2021.*
#
# ## Barren Plateaus
#
# `Barren plateaus <demos/tutorial_barren_plateaus>`{.interpreted-text
# role="doc"} are large regions of the cost function\'s parameter space
# where the variance of the gradient is almost 0; or, put another way, the
# cost function landscape is flat. This means that a variational circuit
# initialized in one of these areas will be untrainable using any
# gradient-based algorithm.
#
# In [\"Cost-Function-Dependent Barren Plateaus in Shallow Quantum Neural
# Networks\"](https://arxiv.org/abs/2001.00550), Cerezo et al. demonstrate
# the idea that the barren plateau phenomenon can, under some
# circumstances, be avoided by using cost functions that only have
# information from part of the circuit. These *local* cost functions can
# be more robust against noise, and may have better-behaved gradients with
# no plateaus for shallow circuits.
#
# <figure>
# <img
# src="https://github.com/borbysh/quantum-barren-plateaus/blob/main/_static/demonstration_assets/local_cost_functions/Cerezo_et_al_local_cost_functions.png?raw=1"
# class="align-center" style="width:50.0%"
# alt="../_static/demonstration_assets/local_cost_functions/Cerezo_et_al_local_cost_functions.png" />
# <figcaption>Taken from Cerezo et al..</figcaption>
# </figure>
#
# Many variational quantum algorithms are constructed to use global cost
# functions. Information from the entire measurement is used to analyze
# the result of the circuit, and a cost function is calculated from this
# to quantify the circuit\'s performance. A local cost function only
# considers information from a few qubits, and attempts to analyze the
# behavior of the entire circuit from this limited scope.
#
# Cerezo et al. also handily prove that these local cost functions are
# bounded by the global ones, i.e., if a global cost function is
# formulated in the manner described by Cerezo et al., then the value of
# its corresponding local cost function will always be less than or equal
# to the value of the global cost function.
#
# In this notebook, we investigate the effect of barren plateaus in
# variational quantum algorithms, and how they can be mitigated using
# local cost functions.
#
# We first need to import the following modules.

# %%
import pennylane as qml
from pennylane import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import LinearLocator, FormatStrFormatter

np.random.seed(42)

# %%
"""Signum optimizer"""
from numpy import sqrt, sign

#from .gradient_descent import GradientDescentOptimizer
from pennylane import GradientDescentOptimizer



class SignumOptimizer(GradientDescentOptimizer):
    r"""Gradient-descent optimizer with adaptive learning rate, first and second moment.

    Adaptive Moment Estimation uses a step-dependent learning rate,
    a first moment :math:`a` and a second moment :math:`b`, reminiscent of
    the momentum and velocity of a particle:

    .. math::
        x^{(t+1)} = x^{(t)} - \eta^{(t+1)} \frac{a^{(t+1)}}{\sqrt{b^{(t+1)}} + \epsilon },

    where the update rules for the two moments are given by

    .. math::
        a^{(t+1)} &= \beta_1 a^{(t)} + (1-\beta_1) \nabla f(x^{(t)}),\\
        b^{(t+1)} &= \beta_2 b^{(t)} + (1-\beta_2) (\nabla f(x^{(t)}))^{\odot 2},\\
        \eta^{(t+1)} &= \eta \frac{\sqrt{(1-\beta_2^{t+1})}}{(1-\beta_1^{t+1})}.

    Above, :math:`( \nabla f(x^{(t-1)}))^{\odot 2}` denotes the element-wise square operation,
    which means that each element in the gradient is multiplied by itself. The hyperparameters
    :math:`\beta_1` and :math:`\beta_2` can also be step-dependent. Initially, the first and
    second moment are zero.

    The shift :math:`\epsilon` avoids division by zero.

    For more details, see `arXiv:1412.6980 <https://arxiv.org/abs/1412.6980>`_.

    Args:
        stepsize (float): the user-defined hyperparameter :math:`\eta`
        beta1 (float): hyperparameter governing the update of the first and second moment
        beta2 (float): hyperparameter governing the update of the first and second moment
        eps (float): offset :math:`\epsilon` added for numerical stability

    .. note::

        When using ``torch``, ``tensorflow`` or ``jax`` interfaces, refer to :doc:`Gradients and training </introduction/interfaces>` for suitable optimizers.

    """

    def __init__(self, stepsize=0.01, beta1=0.9, beta2=0.99):
        super().__init__(stepsize)
        self.beta1 = beta1
        self.beta2 = beta2
        self.accumulation = None



    def apply_grad(self, grad, args):
        r"""Update the variables args to take a single optimization step. Flattens and unflattens
        the inputs to maintain nested iterables as the parameters of the optimization.

        Args:
            grad (tuple[ndarray]): the gradient of the objective
                function at point :math:`x^{(t)}`: :math:`\nabla f(x^{(t)})`
            args (tuple): the current value of the variables :math:`x^{(t)}`

        Returns:
            list: the new values :math:`x^{(t+1)}`
        """
        args_new = list(args)

        if self.accumulation is None:
            self.accumulation = {"dx": [0] * len(args), "dx_sgn": [0] * len(args), "t": 0}

        self.accumulation["t"] += 1

        bias_correction1 = 1 - self.beta1 ** self.accumulation["t"]


        trained_index = 0
        for index, arg in enumerate(args):
            if getattr(arg, "requires_grad", False):
                self._update_accumulation(index, grad[trained_index])
                args_new[index] = arg + self.accumulation["dx"][index] / bias_correction1

                trained_index += 1

        return args_new


    def _update_accumulation(self, index, grad):
        r"""Update the moments.

        Args:
            index (int): the index of the argument to update
            grad (ndarray): the gradient for that trainable param
        """

        bias_correction2 = 1 - self.beta2 ** self.accumulation["t"]

        #bias_correction1 = 1 - self.beta1 ** self.accumulation["t"]

        previous_step = self.accumulation["dx"][index] #/ bias_correction1

        # update the step-sign correlator
        self.accumulation["dx_sgn"][index] = (
            self.beta2 * self.accumulation["dx_sgn"][index] + (1 - self.beta2) * sign(grad) * previous_step
        )

        cross_correlator = self.accumulation["dx_sgn"][index] / bias_correction2

        # Calculate the learning rate
        lr = self.beta1 * cross_correlator + sqrt((self.beta1 * cross_correlator)**2 + (1 - self.beta1**2) * self.stepsize**2)

        # update momentum
        self.accumulation["dx"][index] = (
            self.beta1 * self.accumulation["dx"][index] - lr * sign(grad)
        )


    def reset(self):
        """Reset optimizer by erasing memory of past steps."""
        self.accumulation = None


    @property
    def dx(self):
        """Returns estimated momentum"""
        return None if self.accumulation is None else self.accumulation["dx"]

    @property
    def dx_sgn(self):
        """Returns estimated cross-correlator"""
        return None if self.accumulation is None else self.accumulation["dx_sgn"]

    @property
    def t(self):
        """Returns accumulated timesteps"""
        return None if self.accumulation is None else self.accumulation["t"]

# %% [markdown]
# # Visualizing the problem
#
# To start, let\'s look at the task of learning the identity gate across
# multiple qubits. This will help us visualize the problem and get a sense
# of what is happening in the cost landscape.
#
# First we define a number of wires we want to train on. The work by
# Cerezo et al. shows that circuits are trainable under certain regimes,
# so how many qubits we train on will effect our results.

# %%
wires = 6
dev = qml.device("lightning.qubit", wires=wires, shots=10000)

# %% [markdown]
# Next, we want to define our QNodes and our circuit ansatz. For this
# simple example, an ansatz that works well is simply a rotation along X,
# and a rotation along Y, repeated across all the qubits.
#
# We will also define our cost functions here. Since we are trying to
# learn the identity gate, a natural cost function is 1 minus the
# probability of measuring the zero state, denoted here as
# $1 - p_{|0\rangle}.$
#
# $$C = \langle  \psi(\theta) | \left(I - |0\rangle \langle 0|\right)  | \psi(\theta)  \rangle   =1-p_{|0\rangle}$$
#
# We will apply this across all qubits for our global cost function, i.e.,
#
# $$C_{G} = \langle  \psi(\theta) | \left(I - |00 \ldots 0\rangle \langle 00 \ldots 0|\right) | \psi(\theta) \rangle  = 1-p_{|00 \ldots 0\rangle}$$
#
# and for the local cost function, we will sum the individual
# contributions from each qubit:
#
# $$C_L = \langle \psi(\theta) | \left(I - \frac{1}{n} \sum_j |0\rangle \langle 0|_j\right)|\psi(\theta)\rangle = 1 - \sum_j p_{|0\rangle_j}.$$
#
# It might be clear to some readers now why this function can perform
# better. By formatting our local cost function in this way, we have
# essentially divided the problem up into multiple single-qubit terms, and
# summed all the results up.
#
# To implement this, we will define a separate QNode for the local cost
# function and the global cost function.

# %%
def global_cost_simple(rotations):
    for i in range(wires):
        qml.RX(rotations[0][i], wires=i)
        qml.RY(rotations[1][i], wires=i)
    return qml.probs(wires=range(wires))

def local_cost_simple(rotations):
    for i in range(wires):
        qml.RX(rotations[0][i], wires=i)
        qml.RY(rotations[1][i], wires=i)
    return [qml.probs(wires=i) for i in range(wires)]

global_circuit = qml.QNode(global_cost_simple, dev, interface="autograd")

local_circuit = qml.QNode(local_cost_simple, dev, interface="autograd")

def cost_local(rotations):
    return 1 - np.sum([i for (i, _) in local_circuit(rotations)]) / wires

def cost_global(rotations):
    return 1 - global_circuit(rotations)[0]

# %% [markdown]
# To analyze each of the circuits, we provide some random initial
# parameters for each rotation.

# %%
RX = np.random.uniform(low=-np.pi, high=np.pi)
RY = np.random.uniform(low=-np.pi, high=np.pi)
rotations = [[RX for i in range(wires)], [RY for i in range(wires)]]

# %% [markdown]
# Examining the results:

# %%
print("Global Cost: {: .7f}".format(cost_global(rotations)))
print("Local Cost: {: .7f}".format(cost_local(rotations)))

qml.drawer.use_style('black_white')
fig1, ax1 = qml.draw_mpl(global_circuit, decimals=2)(rotations)
fig1.suptitle("Global Cost", fontsize='xx-large')
plt.show()

fig2, ax2 = qml.draw_mpl(local_circuit, decimals=2)(rotations)
fig2.suptitle("Local Cost", fontsize='xx-large')
plt.show()
# Out:
# Global Cost:  0.9694000
# Local Cost:  0.4423667

# %% [markdown]
# With this simple example, we can visualize the cost function, and see
# the barren plateau effect graphically. Although there are $2n$ (where
# $n$ is the number of qubits) parameters, in order to plot the cost
# landscape we must constrain ourselves. We will consider the case where
# all X rotations have the same value, and all the Y rotations have the
# same value.
#
# Firstly, we look at the global cost function. When plotting the cost
# function across 6 qubits, much of the cost landscape is flat, and
# difficult to train (even with a circuit depth of only 2!). This effect
# will worsen as the number of qubits increases.

# %%
def generate_surface(cost_function):
    Z = []
    Z_assembler = []

    X = np.arange(-np.pi, np.pi, 0.25)
    Y = np.arange(-np.pi, np.pi, 0.25)
    X, Y = np.meshgrid(X, Y)

    for x in X[0, :]:
        for y in Y[:, 0]:
            rotations = [[x for i in range(wires)], [y for i in range(wires)]]
            Z_assembler.append(cost_function(rotations))
        Z.append(Z_assembler)
        Z_assembler = []

    Z = np.asarray(Z)
    return Z

def plot_surface(surface):
    X = np.arange(-np.pi, np.pi, 0.25)
    Y = np.arange(-np.pi, np.pi, 0.25)
    X, Y = np.meshgrid(X, Y)
    fig = plt.figure()
    ax = fig.add_subplot(111, projection="3d")
    surf = ax.plot_surface(X, Y, surface, cmap="viridis", linewidth=0, antialiased=False)
    ax.set_zlim(0, 1)
    ax.zaxis.set_major_locator(LinearLocator(10))
    ax.zaxis.set_major_formatter(FormatStrFormatter("%.02f"))
    plt.show()


global_surface = generate_surface(cost_global)
plot_surface(global_surface)

# %% [markdown]
# However, when we change to the local cost function, the cost landscape
# becomes much more trainable as the size of the barren plateau decreases.

# %%
local_surface = generate_surface(cost_local)
plot_surface(local_surface)

# %% [markdown]
# Those are some nice pictures, but how do they reflect actual
# trainability? Let us try training both the local and global cost
# functions. To simplify this model, let\'s modify our cost function from
#
# $$C_{L} = 1-\sum p_{|0\rangle},$$
#
# where we sum the marginal probabilities of each qubit, to
#
# $$C_{L} = 1-p_{|0\rangle},$$
#
# where we only consider the probability of a single qubit to be in the 0
# state.
#
# While we\'re at it, let us make our ansatz a little more like one we
# would encounter while trying to solve a VQE problem, and add
# entanglement.

# %%
def global_cost_simple(rotations):
    for i in range(wires):
        qml.RX(rotations[0][i], wires=i)
        qml.RY(rotations[1][i], wires=i)
    for i in range(wires - 1):
        qml.CNOT([i, i + 1])
    return qml.probs(wires=range(wires))

def local_cost_simple(rotations):
    for i in range(wires):
        qml.RX(rotations[0][i], wires=i)
        qml.RY(rotations[1][i], wires=i)
    for i in range(wires - 1):
        qml.CNOT([i, i + 1])
    return qml.probs(wires=[0])

global_circuit = qml.QNode(global_cost_simple, dev, interface="autograd")

local_circuit = qml.QNode(local_cost_simple, dev, interface="autograd")

def cost_local(rotations):
    return 1 - local_circuit(rotations)[0]

def cost_global(rotations):
    return 1 - global_circuit(rotations)[0]

# %% [markdown]
# Of course, now that we\'ve changed both our cost function and our
# circuit, we will need to scan the cost landscape again.

# %%
global_surface = generate_surface(cost_global)
plot_surface(global_surface)

local_surface = generate_surface(cost_local)
plot_surface(local_surface)

# %% [markdown]
# It seems our changes didn\'t significantly alter the overall cost
# landscape. This probably isn\'t a general trend, but it is a nice
# surprise. Now, let us get back to training the local and global cost
# functions. Because we have a visualization of the total cost landscape,
# let\'s pick a point to exaggerate the problem. One of the worst points
# in the landscape is $(\pi,0)$ as it is in the middle of the plateau, so
# let\'s use that.

# %%
rotations = np.array([[3.] * len(range(wires)), [0.] * len(range(wires))], requires_grad=True)
opt_sgd = qml.GradientDescentOptimizer(stepsize=0.2)
opt_signum = SignumOptimizer(stepsize = 0.01)
steps = 100
params_global = rotations
for i in range(steps):
    # update the circuit parameters
    params_global = opt_signum.step(cost_global, params_global)

    if (i + 1) % 5 == 0:
        print("Cost after step {:5d}: {: .7f}".format(i + 1, cost_global(params_global)))
    if cost_global(params_global) < 0.1:
        break
fig, ax = qml.draw_mpl(global_circuit, decimals=2)(params_global)
plt.show()
# Out:
# Cost after step     5:  1.0000000
# Cost after step    10:  1.0000000
# Cost after step    15:  1.0000000
# Cost after step    20:  1.0000000
# Cost after step    25:  1.0000000
# Cost after step    30:  1.0000000
# Cost after step    35:  1.0000000
# Cost after step    40:  1.0000000
# Cost after step    45:  1.0000000
# Cost after step    50:  1.0000000
# Cost after step    55:  1.0000000
# Cost after step    60:  1.0000000
# Cost after step    65:  1.0000000
# Cost after step    70:  1.0000000
# Cost after step    75:  1.0000000
# Cost after step    80:  1.0000000
# Cost after step    85:  1.0000000
# Cost after step    90:  1.0000000
# Cost after step    95:  1.0000000
# Cost after step   100:  1.0000000

# %% [markdown]
# After 100 steps, the cost function is still exactly 1. Clearly we are in
# an \"untrainable\" area. Now, let us limit ourselves to the local cost
# function and see how it performs.

# %%
rotations = np.array([[3. for i in range(wires)], [0. for i in range(wires)]], requires_grad=True)
opt_sgd = qml.GradientDescentOptimizer(stepsize=0.2)
opt_signum = SignumOptimizer(stepsize = 0.1)
steps = 100
params_local = rotations
for i in range(steps):
    # update the circuit parameters
    params_local = opt_signum.step(cost_local, params_local)

    if (i + 1) % 5 == 0:
        print("Cost after step {:5d}: {: .7f}".format(i + 1, cost_local(params_local)))
    #if cost_local(params_local) < 0.05:
        #break

fig, ax = qml.draw_mpl(local_circuit, decimals=2)(params_local)
plt.show()
# Out:
# Cost after step     5:  0.5068000
# Cost after step    10:  0.4962000
# Cost after step    15:  0.4761000
# Cost after step    20:  0.2223000
# Cost after step    25:  0.0127000
# Cost after step    30:  0.1189000
# Cost after step    35:  0.0157000
# Cost after step    40:  0.0243000
# Cost after step    45:  0.0058000
# Cost after step    50:  0.0097000
# Cost after step    55:  0.0087000
# Cost after step    60:  0.0025000
# Cost after step    65:  0.0003000
# Cost after step    70:  0.0031000
# Cost after step    75:  0.0021000
# Cost after step    80:  0.0007000
# Cost after step    85:  0.0014000
# Cost after step    90:  0.0008000
# Cost after step    95:  0.0026000
# Cost after step   100:  0.0072000

# %% [markdown]
# It trained! And much faster than the global case. However, we know our
# local cost function is bounded by the global one, but just how much have
# we trained it?

# %%
cost_global(params_local)
# Out:
# np.float64(1.0)

# %% [markdown]
# Interestingly, the global cost function is still 1. If we trained the
# local cost function, why hasn\'t the global cost function changed?
#
# The answer is that we have trained the global cost a *little bit*, but
# not enough to see a change with only 10000 shots. To see the effect,
# we\'ll need to increase the number of shots to an unreasonable amount.
# Instead, making the backend analytic by setting shots to `None`, gives
# us the exact representation.

# %%
_dev = qml.device("lightning.qubit", wires=wires, shots=None)
global_circuit = qml.QNode(global_cost_simple, _dev, interface="autograd")
print(
    "Current cost: "
    + str(cost_global(params_local))
    + ".\nInitial cost: "
    + str(cost_global([[3.0 for i in range(wires)], [0 for i in range(wires)]]))
    + ".\nDifference: "
    + str(
        cost_global([[3.0 for i in range(wires)], [0 for i in range(wires)]])
        - cost_global(params_local)
    )
)
# Out:
# Current cost: 0.9999999996834832.
# Initial cost: 0.9999999999999843.
# Difference: 3.1650115861481254e-10

# %% [markdown]
# Our circuit has definitely been trained, but not a useful amount. If we
# attempt to use this circuit, it would act the same as if we never
# trained at all. Furthermore, if we now attempt to train the global cost
# function, we are still firmly in the plateau region. In order to fully
# train the global circuit, we will need to increase the locality
# gradually as we train.

# %%
def tunable_cost_simple(rotations):
    for i in range(wires):
        qml.RX(rotations[0][i], wires=i)
        qml.RY(rotations[1][i], wires=i)
    for i in range(wires - 1):
        qml.CNOT([i, i + 1])
    return qml.probs(range(locality))

def cost_tunable(rotations):
    return 1 - tunable_circuit(rotations)[0]

tunable_circuit = qml.QNode(tunable_cost_simple, dev, interface="autograd")
locality = 2
params_tunable = params_local
fig, ax = qml.draw_mpl(tunable_circuit, decimals=2)(params_tunable)
plt.show()
print(cost_tunable(params_tunable))

locality = 2
opt_sgd = qml.GradientDescentOptimizer(stepsize=0.1)
opt_signum = SignumOptimizer(stepsize = 0.1)
steps = 600
for i in range(steps):
    # update the circuit parameters
    params_tunable = opt_signum.step(cost_tunable, params_tunable)

    runCost = cost_tunable(params_tunable)
    if (i + 1) % 10 == 0:
        print(
            "Cost after step {:5d}: {: .7f}".format(i + 1, runCost)
            + ". Locality: "
            + str(locality)
        )

    if runCost < 0.1 and locality < wires:
        print("---Switching Locality---")
        locality += 1
        continue
    elif runCost < 0.1 and locality >= wires:
        break
fig, ax = qml.draw_mpl(tunable_circuit, decimals=2)(params_tunable)
plt.show()
# Out:
# 0.499
# ---Switching Locality---
# Cost after step    10:  0.2264000. Locality: 3
# ---Switching Locality---
# Cost after step    20:  0.4623000. Locality: 4
# ---Switching Locality---
# Cost after step    30:  0.5221000. Locality: 5
# ---Switching Locality---
# Cost after step    40:  0.8463000. Locality: 6
# Cost after step    50:  0.4585000. Locality: 6

# %% [markdown]
# # A more thorough analysis
#
# Now the circuit can be trained, even though we started from a place
# where the global function has a barren plateau. The significance of this
# is that we can now train from every starting location in this example.
#
# But, how often does this problem occur? If we wanted to train this
# circuit from a random starting point, how often would we be stuck in a
# plateau? To investigate this, let\'s attempt to train the global cost
# function using random starting positions and count how many times we run
# into a barren plateau.
#
# Let\'s use a number of qubits we are more likely to use in a real
# variational circuit: n=10. We will say that after 400 steps, any run
# with a cost function of less than 0.9 (chosen arbitrarily) will probably
# be trainable given more time. Any run with a greater cost function will
# probably be in a plateau.
#
# This may take up to 15 minutes.

# %%
samples = 10
plateau = 0
trained = 0
opt_sgd = qml.GradientDescentOptimizer(stepsize=0.2)
opt_signum = SignumOptimizer(stepsize = 0.01)
opt_adam = qml.AdamOptimizer(stepsize=0.01)
steps = 400
wires = 8

dev = qml.device("lightning.qubit", wires=wires, shots=10000)
global_circuit = qml.QNode(global_cost_simple, dev, interface="autograd")

for runs in range(samples):
    print("--- New run! ---")
    has_been_trained = False

    params_global = np.random.uniform(-np.pi, np.pi, (2, wires), requires_grad=True)

    for i in range(steps):
        # update the circuit parameters
        #params_global = opt_signum.step(cost_global, params_global)
        #params_global = opt_sgd.step(cost_global, params_global)
        params_global = opt_adam.step(cost_global, params_global)

        if (i + 1) % 20 == 0:
            print("Cost after step {:5d}: {: .7f}".format(i + 1, cost_global(params_global)))
        if cost_global(params_global) < 0.9:
            has_been_trained = True
            break
    if has_been_trained:
        trained = trained + 1
    else:
        plateau = plateau + 1
    print("Trained: {:5d}".format(trained))
    print("Plateau'd: {:5d}".format(plateau))


samples = 10
plateau = 0
trained = 0
opt_sgd = qml.GradientDescentOptimizer(stepsize=0.2)
opt_signum = SignumOptimizer(stepsize = 0.01)
opt_adam = qml.AdamOptimizer(stepsize=0.01)
steps = 400
wires = 8

dev = qml.device("lightning.qubit", wires=wires, shots=10000)
tunable_circuit = qml.QNode(tunable_cost_simple, dev, interface="autograd")

for runs in range(samples):
    locality = 1
    print("--- New run! ---")
    has_been_trained = False

    params_tunable = np.random.uniform(-np.pi, np.pi, (2, wires), requires_grad=True)
    for i in range(steps):
        # update the circuit parameters
        #params_tunable = opt_signum.step(cost_tunable, params_tunable)
        #params_tunable = opt_sgd.step(cost_tunable, params_tunable)
        params_tunable = opt_adam.step(cost_tunable, params_tunable)

        runCost = cost_tunable(params_tunable)
        if (i + 1) % 10 == 0:
            print(
                "Cost after step {:5d}: {: .7f}".format(i + 1, runCost)
                + ". Locality: "
                + str(locality)
            )

        if runCost < 0.5 and locality < wires:
            print("---Switching Locality---")
            locality += 1
            continue
        elif runCost < 0.1 and locality >= wires:
            trained = trained + 1
            has_been_trained = True
            break
    if not has_been_trained:
        plateau = plateau + 1
    print("Trained: {:5d}".format(trained))
    print("Plateau'd: {:5d}".format(plateau))
# Out:
# --- New run! ---
# Cost after step    20:  0.9922000
# Cost after step    40:  0.9654000
# Cost after step    60:  0.8990000
# Trained:     1
# Plateau'd:     0
# --- New run! ---
# Cost after step    20:  0.9939000
# Cost after step    40:  0.9767000
# Cost after step    60:  0.9023000
# Trained:     2
# Plateau'd:     0
# --- New run! ---
# Cost after step    20:  0.9984000
# Cost after step    40:  0.9987000
# Cost after step    60:  0.9985000
# Cost after step    80:  0.9972000
# Cost after step   100:  0.9972000
# Cost after step   120:  0.9927000
# Cost after step   140:  0.9840000
# Cost after step   160:  0.9363000
# Trained:     3
# Plateau'd:     0
# --- New run! ---
# Cost after step    20:  0.9981000
# Cost after step    40:  0.9968000
# Cost after step    60:  0.9921000
# Cost after step    80:  0.9728000
# Trained:     4
# Plateau'd:     0
# --- New run! ---
# Cost after step    20:  0.9957000
# Cost after step    40:  0.9885000
# Cost after step    60:  0.9652000
# Trained:     5
# Plateau'd:     0
# --- New run! ---
# Cost after step    20:  0.9979000
# Cost after step    40:  0.9962000
# Cost after step    60:  0.9874000
# Cost after step    80:  0.9312000
# Trained:     6
# Plateau'd:     0
# --- New run! ---
# Cost after step    20:  0.9693000
# Cost after step    40:  0.9002000
# Trained:     7
# Plateau'd:     0
# --- New run! ---
# Cost after step    20:  0.9937000
# Cost after step    40:  0.9857000
# Cost after step    60:  0.9700000
# Cost after step    80:  0.9380000
# Trained:     8
# Plateau'd:     0
# --- New run! ---
# Cost after step    20:  0.9817000
# Cost after step    40:  0.9534000
# Trained:     9
# Plateau'd:     0
# --- New run! ---
# Cost after step    20:  0.9949000
# Cost after step    40:  0.9894000
# Cost after step    60:  0.9812000
# Cost after step    80:  0.9470000
# Trained:    10
# Plateau'd:     0
# --- New run! ---
# ---Switching Locality---
# Cost after step    10:  0.9611000. Locality: 2
# Cost after step    20:  0.9336000. Locality: 2
# Cost after step    30:  0.8986000. Locality: 2
# Cost after step    40:  0.8559000. Locality: 2
# Cost after step    50:  0.8047000. Locality: 2
# Cost after step    60:  0.7395000. Locality: 2
# Cost after step    70:  0.6722000. Locality: 2
# Cost after step    80:  0.6200000. Locality: 2
# Cost after step    90:  0.5741000. Locality: 2
# Cost after step   100:  0.5384000. Locality: 2
# Cost after step   110:  0.5276000. Locality: 2
# Cost after step   120:  0.5138000. Locality: 2
# Cost after step   130:  0.4999000. Locality: 2
# ---Switching Locality---
# Cost after step   140:  0.6318000. Locality: 3
# Cost after step   150:  0.5912000. Locality: 3
# Cost after step   160:  0.5436000. Locality: 3
# Cost after step   170:  0.5107000. Locality: 3
# ---Switching Locality---
# Cost after step   180:  0.9721000. Locality: 4
# Cost after step   190:  0.9417000. Locality: 4
# Cost after step   200:  0.8856000. Locality: 4
# Cost after step   210:  0.8387000. Locality: 4
# Cost after step   220:  0.8031000. Locality: 4
# Cost after step   230:  0.7721000. Locality: 4
# Cost after step   240:  0.7427000. Locality: 4
# Cost after step   250:  0.7197000. Locality: 4
# Cost after step   260:  0.7045000. Locality: 4
# Cost after step   270:  0.6800000. Locality: 4
# Cost after step   280:  0.6456000. Locality: 4
# Cost after step   290:  0.5948000. Locality: 4
# Cost after step   300:  0.5171000. Locality: 4
# ---Switching Locality---
# Cost after step   310:  0.4843000. Locality: 5
# ---Switching Locality---
# Cost after step   320:  0.9356000. Locality: 6
# Cost after step   330:  0.8605000. Locality: 6
# Cost after step   340:  0.7732000. Locality: 6
# Cost after step   350:  0.6958000. Locality: 6
# Cost after step   360:  0.6245000. Locality: 6
# Cost after step   370:  0.5703000. Locality: 6
# Cost after step   380:  0.5297000. Locality: 6
# Cost after step   390:  0.5168000. Locality: 6
# ---Switching Locality---
# Cost after step   400:  0.9470000. Locality: 7
# Trained:     0
# Plateau'd:     1
# --- New run! ---
# ---Switching Locality---
# Cost after step    10:  0.5582000. Locality: 2
# ---Switching Locality---
# Cost after step    20:  0.8001000. Locality: 3
# Cost after step    30:  0.7140000. Locality: 3
# Cost after step    40:  0.6192000. Locality: 3
# Cost after step    50:  0.5281000. Locality: 3
# ---Switching Locality---
# Cost after step    60:  0.7831000. Locality: 4
# Cost after step    70:  0.7101000. Locality: 4
# Cost after step    80:  0.6034000. Locality: 4
# Cost after step    90:  0.5061000. Locality: 4
# ---Switching Locality---
# Cost after step   100:  0.5478000. Locality: 5
# ---Switching Locality---
# ---Switching Locality---
# Cost after step   110:  0.5882000. Locality: 7
# ---Switching Locality---
# Cost after step   120:  0.8813000. Locality: 8
# Cost after step   130:  0.7961000. Locality: 8
# Cost after step   140:  0.6972000. Locality: 8
# Cost after step   150:  0.6164000. Locality: 8
# Cost after step   160:  0.5307000. Locality: 8
# Cost after step   170:  0.4535000. Locality: 8
# Cost after step   180:  0.3580000. Locality: 8
# Cost after step   190:  0.2535000. Locality: 8
# Cost after step   200:  0.1777000. Locality: 8
# Cost after step   210:  0.1096000. Locality: 8
# Trained:     1
# Plateau'd:     1
# --- New run! ---
# Cost after step    10:  0.6087000. Locality: 1
# Cost after step    20:  0.4986000. Locality: 1
# ---Switching Locality---
# Cost after step    30:  0.9386000. Locality: 2
# Cost after step    40:  0.8916000. Locality: 2
# Cost after step    50:  0.8335000. Locality: 2
# Cost after step    60:  0.7609000. Locality: 2
# Cost after step    70:  0.6830000. Locality: 2
# Cost after step    80:  0.5973000. Locality: 2
# Cost after step    90:  0.5098000. Locality: 2
# ---Switching Locality---
# Cost after step   100:  0.7178000. Locality: 3
# Cost after step   110:  0.6491000. Locality: 3
# Cost after step   120:  0.5617000. Locality: 3
# ---Switching Locality---
# Cost after step   130:  0.9344000. Locality: 4
# Cost after step   140:  0.8890000. Locality: 4
# Cost after step   150:  0.8275000. Locality: 4
# Cost after step   160:  0.7653000. Locality: 4
# Cost after step   170:  0.6964000. Locality: 4
# Cost after step   180:  0.6369000. Locality: 4
# Cost after step   190:  0.5891000. Locality: 4
# Cost after step   200:  0.5496000. Locality: 4
# Cost after step   210:  0.5372000. Locality: 4
# Cost after step   220:  0.5345000. Locality: 4
# Cost after step   230:  0.5124000. Locality: 4
# Cost after step   240:  0.5073000. Locality: 4
# ---Switching Locality---
# Cost after step   250:  0.8339000. Locality: 5
# Cost after step   260:  0.7915000. Locality: 5
# Cost after step   270:  0.7538000. Locality: 5
# Cost after step   280:  0.7250000. Locality: 5
# Cost after step   290:  0.7108000. Locality: 5
# Cost after step   300:  0.6774000. Locality: 5
# Cost after step   310:  0.6332000. Locality: 5
# Cost after step   320:  0.5484000. Locality: 5
# ---Switching Locality---
# Cost after step   330:  0.6101000. Locality: 6
# ---Switching Locality---
# Cost after step   340:  0.5972000. Locality: 7
# ---Switching Locality---
# Cost after step   350:  0.5222000. Locality: 8
# Cost after step   360:  0.3580000. Locality: 8
# Cost after step   370:  0.1883000. Locality: 8
# Trained:     2
# Plateau'd:     1
# --- New run! ---
# ---Switching Locality---
# Cost after step    10:  0.5213000. Locality: 2
# ---Switching Locality---
# Cost after step    20:  0.8356000. Locality: 3
# Cost after step    30:  0.7748000. Locality: 3
# Cost after step    40:  0.6863000. Locality: 3
# Cost after step    50:  0.5916000. Locality: 3
# ---Switching Locality---
# Cost after step    60:  0.8709000. Locality: 4
# Cost after step    70:  0.8218000. Locality: 4
# Cost after step    80:  0.7714000. Locality: 4
# Cost after step    90:  0.6953000. Locality: 4
# Cost after step   100:  0.6298000. Locality: 4
# Cost after step   110:  0.5964000. Locality: 4
# Cost after step   120:  0.5600000. Locality: 4
# Cost after step   130:  0.5261000. Locality: 4
# Cost after step   140:  0.5042000. Locality: 4
# ---Switching Locality---
# Cost after step   150:  0.7147000. Locality: 5
# Cost after step   160:  0.6625000. Locality: 5
# Cost after step   170:  0.6081000. Locality: 5
# Cost after step   180:  0.5047000. Locality: 5
# ---Switching Locality---
# Cost after step   190:  0.8644000. Locality: 6
# Cost after step   200:  0.7876000. Locality: 6
# Cost after step   210:  0.7038000. Locality: 6
# Cost after step   220:  0.6366000. Locality: 6
# Cost after step   230:  0.5873000. Locality: 6
# Cost after step   240:  0.5134000. Locality: 6
# ---Switching Locality---
# Cost after step   250:  0.7977000. Locality: 7
# Cost after step   260:  0.7356000. Locality: 7
# Cost after step   270:  0.7006000. Locality: 7
# Cost after step   280:  0.6504000. Locality: 7
# Cost after step   290:  0.6030000. Locality: 7
# Cost after step   300:  0.5571000. Locality: 7
# ---Switching Locality---
# Cost after step   310:  0.9912000. Locality: 8
# Cost after step   320:  0.9688000. Locality: 8
# Cost after step   330:  0.9260000. Locality: 8
# Cost after step   340:  0.8614000. Locality: 8
# Cost after step   350:  0.7897000. Locality: 8
# Cost after step   360:  0.7068000. Locality: 8
# Cost after step   370:  0.6337000. Locality: 8
# Cost after step   380:  0.5601000. Locality: 8
# Cost after step   390:  0.5208000. Locality: 8
# Cost after step   400:  0.4711000. Locality: 8
# Trained:     2
# Plateau'd:     2
# --- New run! ---
# ---Switching Locality---
# Cost after step    10:  0.6432000. Locality: 2
# Cost after step    20:  0.5078000. Locality: 2
# ---Switching Locality---
# Cost after step    30:  0.7979000. Locality: 3
# Cost after step    40:  0.7172000. Locality: 3
# Cost after step    50:  0.6435000. Locality: 3
# Cost after step    60:  0.5826000. Locality: 3
# Cost after step    70:  0.5287000. Locality: 3
# ---Switching Locality---
# Cost after step    80:  0.6363000. Locality: 4
# Cost after step    90:  0.5403000. Locality: 4
# ---Switching Locality---
# Cost after step   100:  0.7515000. Locality: 5
# Cost after step   110:  0.6452000. Locality: 5
# Cost after step   120:  0.5296000. Locality: 5
# ---Switching Locality---
# Cost after step   130:  0.5486000. Locality: 6
# ---Switching Locality---
# Cost after step   140:  0.9137000. Locality: 7
# Cost after step   150:  0.8577000. Locality: 7
# Cost after step   160:  0.7800000. Locality: 7
# Cost after step   170:  0.6913000. Locality: 7
# Cost after step   180:  0.6042000. Locality: 7
# Cost after step   190:  0.5061000. Locality: 7
# ---Switching Locality---
# Cost after step   200:  0.8034000. Locality: 8
# Cost after step   210:  0.7455000. Locality: 8
# Cost after step   220:  0.6818000. Locality: 8
# Cost after step   230:  0.6408000. Locality: 8
# Cost after step   240:  0.5973000. Locality: 8
# Cost after step   250:  0.5446000. Locality: 8
# Cost after step   260:  0.4666000. Locality: 8
# Cost after step   270:  0.3711000. Locality: 8
# Cost after step   280:  0.2730000. Locality: 8
# Cost after step   290:  0.1824000. Locality: 8
# Cost after step   300:  0.0982000. Locality: 8
# Trained:     3
# Plateau'd:     2
# --- New run! ---
# ---Switching Locality---
# Cost after step    10:  0.7311000. Locality: 2
# Cost after step    20:  0.6296000. Locality: 2
# Cost after step    30:  0.5504000. Locality: 2
# Cost after step    40:  0.5145000. Locality: 2
# Cost after step    50:  0.4974000. Locality: 2
# ---Switching Locality---
# Cost after step    60:  0.9487000. Locality: 3
# Cost after step    70:  0.9136000. Locality: 3
# Cost after step    80:  0.8771000. Locality: 3
# Cost after step    90:  0.8263000. Locality: 3
# Cost after step   100:  0.7966000. Locality: 3
# Cost after step   110:  0.7673000. Locality: 3
# Cost after step   120:  0.7555000. Locality: 3
# Cost after step   130:  0.7380000. Locality: 3
# Cost after step   140:  0.7312000. Locality: 3
# Cost after step   150:  0.7041000. Locality: 3
# Cost after step   160:  0.6820000. Locality: 3
# Cost after step   170:  0.6522000. Locality: 3
# Cost after step   180:  0.6001000. Locality: 3
# Cost after step   190:  0.5447000. Locality: 3
# ---Switching Locality---
# Cost after step   200:  0.5739000. Locality: 4
# ---Switching Locality---
# Cost after step   210:  0.8631000. Locality: 5
# Cost after step   220:  0.7848000. Locality: 5
# Cost after step   230:  0.6841000. Locality: 5
# Cost after step   240:  0.5931000. Locality: 5
# Cost after step   250:  0.4939000. Locality: 5
# ---Switching Locality---
# ---Switching Locality---
# Cost after step   260:  0.7043000. Locality: 7
# Cost after step   270:  0.6601000. Locality: 7
# Cost after step   280:  0.5962000. Locality: 7
# Cost after step   290:  0.4957000. Locality: 7
# ---Switching Locality---
# Cost after step   300:  0.4064000. Locality: 8
# Cost after step   310:  0.2676000. Locality: 8
# Cost after step   320:  0.1493000. Locality: 8
# Trained:     4
# Plateau'd:     2
# --- New run! ---
# ---Switching Locality---
# Cost after step    10:  0.8175000. Locality: 2
# Cost after step    20:  0.7291000. Locality: 2
# Cost after step    30:  0.6223000. Locality: 2
# Cost after step    40:  0.5208000. Locality: 2
# ---Switching Locality---
# Cost after step    50:  0.6149000. Locality: 3
# Cost after step    60:  0.5129000. Locality: 3
# ---Switching Locality---
# Cost after step    70:  0.7619000. Locality: 4
# Cost after step    80:  0.6983000. Locality: 4
# Cost after step    90:  0.6433000. Locality: 4
# Cost after step   100:  0.5957000. Locality: 4
# Cost after step   110:  0.5248000. Locality: 4
# ---Switching Locality---
# Cost after step   120:  0.7558000. Locality: 5
# Cost after step   130:  0.7021000. Locality: 5
# Cost after step   140:  0.6370000. Locality: 5
# Cost after step   150:  0.5809000. Locality: 5
# Cost after step   160:  0.5024000. Locality: 5
# ---Switching Locality---
# ---Switching Locality---
# Cost after step   170:  0.8800000. Locality: 7
# Cost after step   180:  0.8112000. Locality: 7
# Cost after step   190:  0.7225000. Locality: 7
# Cost after step   200:  0.6402000. Locality: 7
# Cost after step   210:  0.5604000. Locality: 7
# ---Switching Locality---
# Cost after step   220:  0.8188000. Locality: 8
# Cost after step   230:  0.7437000. Locality: 8
# Cost after step   240:  0.6916000. Locality: 8
# Cost after step   250:  0.6440000. Locality: 8
# Cost after step   260:  0.6034000. Locality: 8
# Cost after step   270:  0.5411000. Locality: 8
# Cost after step   280:  0.4821000. Locality: 8
# Cost after step   290:  0.3724000. Locality: 8
# Cost after step   300:  0.2597000. Locality: 8
# Cost after step   310:  0.1590000. Locality: 8
# Trained:     5
# Plateau'd:     2
# --- New run! ---
# Cost after step    10:  0.6493000. Locality: 1
# Cost after step    20:  0.5461000. Locality: 1
# ---Switching Locality---
# Cost after step    30:  0.7033000. Locality: 2
# Cost after step    40:  0.6475000. Locality: 2
# Cost after step    50:  0.5628000. Locality: 2
# ---Switching Locality---
# Cost after step    60:  0.8932000. Locality: 3
# Cost after step    70:  0.8312000. Locality: 3
# Cost after step    80:  0.7566000. Locality: 3
# Cost after step    90:  0.6748000. Locality: 3
# Cost after step   100:  0.5842000. Locality: 3
# Cost after step   110:  0.5132000. Locality: 3
# ---Switching Locality---
# Cost after step   120:  0.8171000. Locality: 4
# Cost after step   130:  0.7385000. Locality: 4
# Cost after step   140:  0.6482000. Locality: 4
# Cost after step   150:  0.5419000. Locality: 4
# ---Switching Locality---
# Cost after step   160:  0.6841000. Locality: 5
# Cost after step   170:  0.6047000. Locality: 5
# Cost after step   180:  0.4900000. Locality: 5
# ---Switching Locality---
# Cost after step   190:  0.5028000. Locality: 6
# ---Switching Locality---
# Cost after step   200:  0.5685000. Locality: 7
# ---Switching Locality---
# Cost after step   210:  0.8496000. Locality: 8
# Cost after step   220:  0.7862000. Locality: 8
# Cost after step   230:  0.6978000. Locality: 8
# Cost after step   240:  0.6242000. Locality: 8
# Cost after step   250:  0.5547000. Locality: 8
# Cost after step   260:  0.4837000. Locality: 8
# Cost after step   270:  0.4134000. Locality: 8
# Cost after step   280:  0.3309000. Locality: 8
# Cost after step   290:  0.2463000. Locality: 8
# Cost after step   300:  0.1568000. Locality: 8
# Trained:     6
# Plateau'd:     2
# --- New run! ---
# ---Switching Locality---
# Cost after step    10:  0.7922000. Locality: 2
# Cost after step    20:  0.7094000. Locality: 2
# Cost after step    30:  0.6292000. Locality: 2
# Cost after step    40:  0.5639000. Locality: 2
# Cost after step    50:  0.5393000. Locality: 2
# Cost after step    60:  0.5145000. Locality: 2
# ---Switching Locality---
# Cost after step    70:  0.9452000. Locality: 3
# Cost after step    80:  0.9080000. Locality: 3
# Cost after step    90:  0.8648000. Locality: 3
# Cost after step   100:  0.8113000. Locality: 3
# Cost after step   110:  0.7523000. Locality: 3
# Cost after step   120:  0.6782000. Locality: 3
# Cost after step   130:  0.6041000. Locality: 3
# Cost after step   140:  0.5037000. Locality: 3
# ---Switching Locality---
# Cost after step   150:  0.8759000. Locality: 4
# Cost after step   160:  0.8119000. Locality: 4
# Cost after step   170:  0.7388000. Locality: 4
# Cost after step   180:  0.6499000. Locality: 4
# Cost after step   190:  0.5805000. Locality: 4
# Cost after step   200:  0.4958000. Locality: 4
# ---Switching Locality---
# Cost after step   210:  0.6357000. Locality: 5
# Cost after step   220:  0.5368000. Locality: 5
# ---Switching Locality---
# Cost after step   230:  0.7783000. Locality: 6
# Cost after step   240:  0.6949000. Locality: 6
# Cost after step   250:  0.5891000. Locality: 6
# ---Switching Locality---
# Cost after step   260:  0.7437000. Locality: 7
# Cost after step   270:  0.6914000. Locality: 7
# Cost after step   280:  0.6473000. Locality: 7
# Cost after step   290:  0.6234000. Locality: 7
# Cost after step   300:  0.5548000. Locality: 7
# ---Switching Locality---
# Cost after step   310:  0.5973000. Locality: 8
# Cost after step   320:  0.4449000. Locality: 8
# Cost after step   330:  0.2929000. Locality: 8
# Cost after step   340:  0.1549000. Locality: 8
# Trained:     7
# Plateau'd:     2
# --- New run! ---
# ---Switching Locality---
# Cost after step    10:  0.7315000. Locality: 2
# Cost after step    20:  0.7323000. Locality: 2
# Cost after step    30:  0.6944000. Locality: 2
# Cost after step    40:  0.6350000. Locality: 2
# Cost after step    50:  0.5384000. Locality: 2
# ---Switching Locality---
# Cost after step    60:  0.8537000. Locality: 3
# Cost after step    70:  0.7672000. Locality: 3
# Cost after step    80:  0.6883000. Locality: 3
# Cost after step    90:  0.5873000. Locality: 3
# Cost after step   100:  0.5269000. Locality: 3
# ---Switching Locality---
# Cost after step   110:  0.9960000. Locality: 4
# Cost after step   120:  0.9893000. Locality: 4
# Cost after step   130:  0.9787000. Locality: 4
# Cost after step   140:  0.9540000. Locality: 4
# Cost after step   150:  0.9182000. Locality: 4
# Cost after step   160:  0.8646000. Locality: 4
# Cost after step   170:  0.8185000. Locality: 4
# Cost after step   180:  0.7529000. Locality: 4
# Cost after step   190:  0.6956000. Locality: 4
# Cost after step   200:  0.6355000. Locality: 4
# Cost after step   210:  0.5805000. Locality: 4
# Cost after step   220:  0.5206000. Locality: 4
# ---Switching Locality---
# Cost after step   230:  0.6010000. Locality: 5
# Cost after step   240:  0.4972000. Locality: 5
# ---Switching Locality---
# Cost after step   250:  0.5864000. Locality: 6
# ---Switching Locality---
# Cost after step   260:  0.6558000. Locality: 7
# Cost after step   270:  0.5156000. Locality: 7
# ---Switching Locality---
# Cost after step   280:  0.9032000. Locality: 8
# Cost after step   290:  0.8415000. Locality: 8
# Cost after step   300:  0.7483000. Locality: 8
# Cost after step   310:  0.6585000. Locality: 8
# Cost after step   320:  0.5491000. Locality: 8
# Cost after step   330:  0.4327000. Locality: 8
# Cost after step   340:  0.3228000. Locality: 8
# Cost after step   350:  0.2320000. Locality: 8
# Cost after step   360:  0.1665000. Locality: 8
# Cost after step   370:  0.1172000. Locality: 8
# Trained:     8
# Plateau'd:     2

# %% [markdown]
# In the global case, anywhere between 70-80% of starting positions are
# untrainable, a significant number. It is likely that, as the complexity
# of our ansatz---and the number of qubits---increases, this factor will
# increase.
#
# We can compare that to our local cost function, where every single area
# trained, and most even trained in less time. While these examples are
# simple, this local-vs-global cost behaviour has been shown to extend to
# more complex problems.

# %% [markdown]
# # References
#
# # About the author
